# %%
import numpy as np
import olmuyo as rb
import matplotlib.pyplot as plt

# %%
nred = rb.rainbow(1.3316)

nblue = rb.rainbow(1.3419)

# %%
fig, axes =plt.subplot(1,2)
axes[0].plt(nblue)
# Out:
# [[180.     ]
#  [170.25922]
#  [160.9347 ]
#  [152.4943 ]
#  [145.51614]
#  [140.75758]
#  [139.22552]
#  [142.20522]
#  [151.14575]]
